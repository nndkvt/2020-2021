# %%
import numpy as np
import pandas as pd
import scipy as sp
import math
import matplotlib.pyplot as plt

from scipy.integrate import odeint

# %%
x0 = 227000
y0 = 139000
t0 = 0

# %%
a = 0.34
b = 0.87
c = 0.51
h = 0.2

# %%
tmax = 2.25
dt = 0.05

# %%
t = np.arange(t0, tmax, dt)
t = np.append(t, tmax)
t
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  , 1.05,
#        1.1 , 1.15, 1.2 , 1.25, 1.3 , 1.35, 1.4 , 1.45, 1.5 , 1.55, 1.6 ,
#        1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 , 1.95, 2.  , 2.05, 2.1 , 2.15,
#        2.2 , 2.25])

# %%
def P(t):
    return (math.sin(t) + 2)

def Q(t):
    return (2 * abs(math.cos(t)))

# %%
def syst(f, t):
    x = f[0]
    y = f[1]
    dxdt = -a*x - b*y + P(t)
    dydt = -c*x - h*y + Q(t)
    return (dxdt, dydt)

# %%
v0 = (x0, y0)

# %%
yf = odeint(syst, v0, t)
yf
# Out:
# array([[227000.        , 139000.        ],
#        [217331.25962104, 131981.23388963],
#        [208121.49242746, 125271.75065217],
#        [199349.93870788, 118857.09435679],
#        [190996.79627424, 112723.46626596],
#        [183043.17633504, 106857.6943714 ],
#        [175471.06970954, 101247.21005034],
#        [168263.29301116,  95880.01088612],
#        [161403.4602518 ,  90744.64104295],
#        [154875.94558606,  85830.16551851],
#        [148665.8476207 ,  81126.14547215],
#        [142758.95563709,  76622.61487339],
#        [137141.71817144,  72310.05877462],
#        [131801.2136738 ,  68179.39301466],
#        [126725.12155774,  64221.94419065],
#        [121901.6934643 ,  60429.42977788],
#        [117319.72709913,  56793.94002032],
#        [112968.54473899,  53307.92303564],
#        [108837.96844684,  49964.16765457],
#        [104918.29248106,  46755.78432557],
#        [101200.26498278,  43676.19240909],
#        [ 97675.06949881,  40719.10735781],
#        [ 94334.30262406,  37878.52522287],
#        [ 91169.95507212,  35148.70952025],
#        [ 88174.39475528,  32524.17948005],
#        [ 85340.34938462,  29999.69796405],
#        [ 82660.89001289,  27570.26003109],
#        [ 80129.4155887 ,  25231.08219794],
#        [ 77739.63798484,  22977.59202508],
#        [ 75485.56791771,  20805.41831491],
#        [ 73361.5014348 ,  18710.38176907],
#        [ 71362.00690253,  16688.48647535],
#        [ 69481.912994  ,  14735.91154864],
#        [ 67716.29657163,  12849.00353403],
#        [ 66060.47152709,  11024.26931022],
#        [ 64509.97831339,   9258.36513856],
#        [ 63060.57359031,   7548.08413212],
#        [ 61708.22090663,   5890.35956455],
#        [ 60449.081282  ,   4282.25512602],
#        [ 59279.50439126,   2720.95870239],
#        [ 58196.02017438,   1203.77647248],
#        [ 57195.33076443,   -271.8727771 ],
#        [ 56274.30288504,  -1708.46301654],
#        [ 55429.9605937 ,  -3108.36610137],
#        [ 54659.47828205,  -4473.85672585],
#        [ 53960.1740723 ,  -5807.11710619]])

# %%
x = []
y = []

for i in range(len(yf)):
    x.append(yf[i][0])
    y.append(yf[i][1])

# %%
zero = []
for i in range(len(t)):
    zero = np.append(zero, 0)

plt.figure(figsize=(12.8, 9.6))
plt.plot(t, zero, 'g')
plt.plot(t, x, 'b', label='X')
plt.plot(t, y, 'r', label='Y')
plt.ylabel("Численность армии", fontsize=20)
plt.xlabel("Время", fontsize=20)
plt.title("Модель боевых действий", fontsize=25)
plt.legend(loc='upper right', fontsize=15)
