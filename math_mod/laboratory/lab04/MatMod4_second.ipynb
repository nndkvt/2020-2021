# %%
import numpy as np
import pandas as pd
import scipy as sp
import math
import matplotlib.pyplot as plt

from scipy.integrate import odeint

# %%
x0 = 2
y0 = -1
tmax = 60
t0 = 0
dt = 0.05

# %%
t = np.arange(t0, tmax, dt)
t = np.append(t, tmax)
t
# Out:
# array([0.000e+00, 5.000e-02, 1.000e-01, ..., 5.990e+01, 5.995e+01,
#        6.000e+01])

# %%
w = math.sqrt(9.0)
g = 7.0 / 2

# %%
def f(t):
    return 0

# %%
def func(y, t):
    dxdt = y[1]
    dydt = -w*w*y[0] - g*2*y[1] - f(t)
    return (dxdt, dydt)

# %%
v0 = (x0, y0)

# %%
yf = odeint(func, v0, t)
yf
# Out:
# array([[ 2.00000000e+00, -1.00000000e+00],
#        [ 1.93791752e+00, -1.45230044e+00],
#        [ 1.85744745e+00, -1.74351175e+00],
#        ...,
#        [-4.49412118e-13,  7.62263638e-13],
#        [-4.48983494e-13,  7.61536638e-13],
#        [-4.48554870e-13,  7.60809638e-13]])

# %%
x = []
y = []
for i in range(len(yf)):
    x = np.append(x, yf[i][0])
    y = np.append(y, yf[i][1])

# %%
plt.figure(figsize=(12.8, 9.6))
plt.grid(True)
plt.title("Колебания гармонического осциллятора c затуханием", fontsize=25)
plt.xlabel("x", fontsize=20)
plt.ylabel("y", fontsize=20)
plt.plot(x, y)
