# %%
import numpy as np
import pandas as pd
import scipy as sp
import math
import matplotlib.pyplot as plt

from scipy.integrate import odeint

# %%
x0 = 2
y0 = -1
tmax = 60
t0 = 0
dt = 0.05

# %%
t = np.arange(t0, tmax, dt)
t = np.append(t, tmax)
t
# Out:
# array([0.000e+00, 5.000e-02, 1.000e-01, ..., 5.990e+01, 5.995e+01,
#        6.000e+01])

# %%
w = math.sqrt(2.4)
g = 0

# %%
def f(t):
    return 0

# %%
def func(y, t):
    dxdt = y[1]
    dydt = -w*w*y[0] - g*2*y[1] - f(t)
    return (dxdt, dydt)

# %%
v0 = (x0, y0)

# %%
yf = odeint(func, v0, t)
yf
# Out:
# array([[ 2.        , -1.        ],
#        [ 1.94405299, -1.23676154],
#        [ 1.87644749, -1.46610626],
#        ...,
#        [ 0.8797025 ,  2.95680771],
#        [ 1.0247573 ,  2.84248296],
#        [ 1.16366663,  2.71111183]])

# %%
x = []
y = []
for i in range(len(yf)):
    x = np.append(x, yf[i][0])
    y = np.append(y, yf[i][1])

# %%
plt.figure(figsize=(12.8, 9.6))
plt.grid(True)
plt.title("Колебания гармонического осциллятора без затуханий", fontsize=25)
plt.xlabel("x", fontsize=20)
plt.ylabel("y", fontsize=20)
plt.plot(x, y)
